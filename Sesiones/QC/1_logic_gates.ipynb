# %% [markdown]
# # Logic gates
#
# Logic gates perform basic logical operations and serve as the building blocks of `digital circuits`. Most logic gates take one or two binary values `(0 or 1)` as inputs and produce a single binary output. Basic circuits contain only a few logic gates, while complex ones — such as microprocessors — may contain millions.
#
# There are eight primary types of logic gates, each with a specific Boolean function. Their names and symbols (used in logic gate diagrams) are listed below.
#
#
#
# [Logic gates](https://techterms.com/img/xl/logic_gate_375.png)
#
# <center><img src="https://techterms.com/img/xl/logic_gate_375.png" width="700"><center>

# %% [markdown]
# ## Truth table
#
# [Truth table](https://www.researchgate.net/figure/Summary-of-the-common-Boolean-logic-gates-with-symbols-and-truth-tables_fig3_291418819)
#
# Summary of the common Boolean logic gates with symbols and truth tables.
#
# <a href="https://www.researchgate.net/figure/Summary-of-the-common-Boolean-logic-gates-with-symbols-and-truth-tables_fig3_291418819"><img src="https://www.researchgate.net/publication/291418819/figure/fig3/AS:718510820962304@1548317737478/Summary-of-the-common-Boolean-logic-gates-with-symbols-and-truth-tables.png" alt="Summary of the common Boolean logic gates with symbols and truth tables."/></a>

# %% [markdown]
# ## Real logic gates in digital circuits
#
# [Circuits for Logig gates](https://mialdeatdo.com/topic/2-5-circuitos-integrados-para-compuertas-logicas/)
#
#
# <img src="figures/real_digital_circuits.png" width="600">
#
# <img src="figures/real_digital_circuits2.png" width="600">

# %% [markdown]
# ## Exercise:
#
# Find the output in every logic gate.
#
# ![](figures/exercise_logic_gates.png)
